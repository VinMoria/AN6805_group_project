# %%
import pandas as pd

# %%
df = pd.read_csv("placementdata.csv")
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
df.groupby("PlacementStatus").count()
# Out:
#                  StudentID  CGPA  Internships  Projects  \
# PlacementStatus
# NotPlaced             5803  5803         5803      5803
# Placed                4197  4197         4197      4197
#
#                  Workshops/Certifications  AptitudeTestScore  \
# PlacementStatus
# NotPlaced                            5803               5803
# Placed                               4197               4197
#
#                  SoftSkillsRating  ExtracurricularActivities  \
# PlacementStatus
# NotPlaced                    5803                       5803
# Placed                       4197                       4197
#
#                  PlacementTraining  SSC_Marks  HSC_Marks
# PlacementStatus
# NotPlaced                     5803       5803       5803
# Placed                        4197       4197       4197

# %%
df.head()
# Out:
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679         1/1/2019  GGOENEBJ079499
# 1       17850           16680         1/1/2019  GGOENEBJ079499
# 2       17850           16681         1/1/2019  GGOEGFKQ020399
# 3       17850           16682         1/1/2019  GGOEGAAB010516
# 4       17850           16682         1/1/2019  GGOEGBJL013999
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status
# 0         1     153.71               6.5          Used
# ...
